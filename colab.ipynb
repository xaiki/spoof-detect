# %%
# !nvidia-smi
# !pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio==0.8.1 -f https://download.pytorch.org/whl/torch_stable.html
# Out:
# Fri Sep 30 06:40:35 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
os.chdir('/content')
# !git clone https://github.com/xaiki/spoof-detect
# !git clone https://github.com/meituan/YOLOv6
# !wget -c https://github.com/meituan/YOLOv6/releases/download/0.1.0/yolov6s.pt
# !mkdir /content/YOLOv6/weights/
# !mv yolov6s.pt /content/YOLOv6/weights/
# Out:
# fatal: destination path 'spoof-detect' already exists and is not an empty directory.
# fatal: destination path 'YOLOv6' already exists and is not an empty directory.
# --2022-09-30 07:11:35--  https://github.com/meituan/YOLOv6/releases/download/0.1.0/yolov6s.pt
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-25404031-1291-4d7a-9d8e-f71c2c60467c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-25404031-1291-4d7a-9d8e-f71c2c60467c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
for d in ['/content/spoof-detect/python', '/content/YOLOv6']:
  os.chdir(d) 
  print(os.system('pip install -r requirements.txt'))
# Out:
# 256
# 0

# %%
# !pwd
# Out:
# /content/YOLOv6

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ls /content/gdrive/MyDrive/data.tar.gz
# !cd /content && tar xvzf /content/gdrive/MyDrive/data.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# data/split/labels/train/00431.12.69-x0y6.txt
# data/split/labels/train/00431.12.69-x1y1.txt
# data/split/labels/train/00431.12.69-x1y2.txt
# data/split/labels/train/00431.12.69-x2y1.txt
# data/split/labels/train/00431.12.69-x2y3.txt
# data/split/labels/train/00431.12.69-x2y4.txt
# data/split/labels/train/00319.12.70-x0y1.txt
# data/split/labels/train/00319.12.70-x0y3.txt
# data/split/labels/train/00319.12.70-x0y7.txt
# data/split/labels/train/00321.13.3-x0y6.txt
# data/split/labels/train/00321.13.3-x0y7.txt
# data/split/labels/train/00321.13.3-x0y8.txt
# data/split/labels/train/00321.13.3-x1y6.txt
# data/split/labels/train/00321.13.3-x1y7.txt
# data/split/labels/train/00321.13.3-x1y8.txt
# data/split/labels/train/00321.13.3-x3y3.txt
# data/split/labels/train/00321.13.3-x3y7.txt
# data/split/labels/train/00321.13.3-x5y7.txt
# data/split/labels/train/00007.13.4-x0y3.txt
# data/split/labels/train/00007.13.4-x0y8.txt
# ...

# %%
# %%writefile /content/data/data.yaml
# # this file is autogenerated by write_data.py for YOLO version 6
#
#
# train: /content/data/split/images/train
# val:   /content/data/split/images/val
# test:  /content/data/split/images/test
#
# is_coco: False
#
#
# nc: 55
# num_classes: 55
# names: ['BACS BANCO DE CREDITO Y SECURITIZAC', 'BANCO BBVA ARGENTINA S.A.', 'BANCO BICA S.A.', 'BANCO CETELEM ARGENTINA S.A.', 'BANCO CMF S.A.', 'BANCO COINAG S.A.', 'BANCO COLUMBIA S.A.', 'BANCO COMAFI SOCIEDAD ANONIMA', 'BANCO CREDICOOP COOPERATIVO LIMITAD', 'BANCO DE COMERCIO S.A.', 'BANCO DE CORRIENTES S.A.', 'BANCO DE FORMOSA S.A.', 'BANCO DE GALICIA Y BUENOS AIRES S.A', 'BANCO DE INVERSION Y COMERCIO EXTER', 'BANCO DE LA CIUDAD DE BUENOS AIRES', 'BANCO DE LA NACION ARGENTINA', 'BANCO DE LA PAMPA SOCIEDAD DE ECONO', 'BANCO DE LA PROVINCIA DE BUENOS AIR', 'BANCO DE LA PROVINCIA DE CORDOBA S.', 'BANCO DE SAN JUAN S.A.', 'BANCO DE SANTA CRUZ S.A.', 'BANCO DE SANTIAGO DEL ESTERO S.A.', 'BANCO DE SERVICIOS FINANCIEROS S.A.', 'BANCO DE SERVICIOS Y TRANSACCIONES ', 'BANCO DE VALORES S.A.', 'BANCO DEL CHUBUT S.A.', 'BANCO DEL SOL S.A.', 'BANCO DINO S.A.', 'BANCO HIPOTECARIO S.A.', 'BANCO INDUSTRIAL S.A.', 'BANCO INTERFINANZAS S.A.', 'BANCO ITAU ARGENTINA S.A.', 'BANCO JULIO SOCIEDAD ANONIMA', 'BANCO MACRO S.A.', 'BANCO MARIVA S.A.', 'BANCO MASVENTAS S.A.', 'BANCO MERIDIAN S.A.', 'BANCO MUNICIPAL DE ROSARIO', 'BANCO PATAGONIA S.A.', 'BANCO PIANO S.A.', 'BANCO PROVINCIA DE TIERRA DEL FUEGO', 'BANCO PROVINCIA DEL NEUQUÉN SOCIEDA', 'BANCO RIOJA SOCIEDAD ANONIMA UNIPER', 'BANCO ROELA S.A.', 'BANCO SAENZ S.A.', 'BANCO SANTANDER RIO S.A.', 'BANCO SUCREDITO REGIONAL S.A.U.', 'BANCO SUPERVIELLE S.A.', 'BANCO VOII S.A.', 'BNP PARIBAS', 'BRUBANK S.A.U.', 'CITIBANK N.A.', 'COMPAÑIA FINANCIERA ARGENTINA S.A.', 'CREDITO REGIONAL COMPAÑIA FINANCIER', 'FCA COMPAÑIA FINANCIERA S.A.']
# Out:
# Overwriting /content/data/data.yaml

# %%
# run this cell to begin training
# !python /content/YOLOv6/tools/train.py --batch 32 --conf configs/yolov6s_finetune.py --epochs 100 --img-size 416 --data /content/data/data.yaml --device 0
# Out:
# Using 1 GPU for training...
# training args are: Namespace(batch_size=32, calib=False, check_images=False, check_labels=False, conf_file='configs/yolov6s_finetune.py', data_path='/content/data/data.yaml', device='0', dist_url='env://', distill=False, distill_feat=False, epochs=100, eval_final_only=False, eval_interval=20, gpu_count=0, heavy_eval_range=50, img_size=416, local_rank=-1, name='exp', output_dir='./runs/train', quant=False, rank=-1, resume=False, save_ckpt_on_last_n_epoch=-1, save_dir='runs/train/exp6', stop_aug_last_n_epoch=15, teacher_model_path=None, temperature=20, workers=8, world_size=1, write_trainbatch_tb=False)
#
# Train: Final numbers of valid images: 51942/ labels: 51942.
# 1.9s for dataset initialization.
# Convert to COCO format
# 100% 6433/6433 [00:00<00:00, 76764.95it/s]
# Convert to COCO format finished. Resutls saved in /content/data/split/annotations/instances_val.json
# Val: Final numbers of valid images: 6433/ labels: 6433.
# ...

# %%
# !nvidia-smi
# Out:
# Fri Sep 30 06:35:51 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
